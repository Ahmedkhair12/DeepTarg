# %% [markdown]
# ## Parsing the CMap
# In this part, the cmapBQ API package will be used to parse the CMap and query the genetic perturbation signatures induced in CNS cell lines and their relevant metadata tables. We will first parse the metadata table of genetic perturbations to collect the IDs of all signatures of this genetic type. Then we will parse the cell information table to select only cell lines from central nervous system lineages. Finally, we will import the disease set of genes (disease signature) to formulate the final query based on the specific signature IDs and the disease gene set we are interested in.

# %%
import os
import pandas as pd
import numpy as np
import requests

# %%
import cmapBQ.query as cmap_query
import cmapBQ.config as cmap_config

# %%
# Get autherization 
# The crediatals file is not uploaded
cmap_config.setup_credentials("./connectivitymap-1ec673279e60.json")
from google.cloud import bigquery
credentials_filepath = "./connectivitymap-1ec673279e60.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credentials_filepath
bq_client = bigquery.Client()

# %% [markdown]
# ### List the CMap tables
# These are the cmap-big-tables that include different levels of data as well as metadata for the experiments. Our target is the table containing level-5 data which are the final signatures.

# %%
import cmapBQ.query as cmap_query

cmap_query.list_tables()
# Out:
# _includes_clustered_tables: <bound method TableDirectory._includes_clustered_tables of TableDirectory(compoundinfo='cmap-big-table.cmap_lincs_public_views.compoundinfo', genetic_pertinfo='cmap-big-table.cmap_lincs_public_views.genetic_pertinfo', geneinfo='cmap-big-table.cmap_lincs_public_views.geneinfo', cellinfo='cmap-big-table.cmap_lincs_public_views.cellinfo', instinfo='cmap-big-table.cmap_lincs_public_views.instinfo', siginfo='cmap-big-table.cmap_lincs_public_views.siginfo', level3='cmap-big-table.cmap_lincs_public_views.L1000_Level3_cid', level3_rid='cmap-big-table.cmap_lincs_public_views.L1000_Level3_rid', level3_landmark='cmap-big-table.cmap_lincs_public_views.L1000_Level3_landmark', level4='cmap-big-table.cmap_lincs_public_views.L1000_Level4_cid', level4_rid='cmap-big-table.cmap_lincs_public_views.L1000_Level4_rid', level4_landmark='cmap-big-table.cmap_lincs_public_views.L1000_Level4_landmark', level5='cmap-big-table.cmap_lincs_public_views.L1000_Level5_cid', level5_rid='cmap-big-table.cmap_lincs_public_views.L1000_Level5_rid', level5_landmark='cmap-big-table.cmap_lincs_public_views.L1000_Level5_landmark')>
# cellinfo: cmap-big-table.cmap_lincs_public_views.cellinfo
# compoundinfo: cmap-big-table.cmap_lincs_public_views.compoundinfo
# geneinfo: cmap-big-table.cmap_lincs_public_views.geneinfo
# genetic_pertinfo: cmap-big-table.cmap_lincs_public_views.genetic_pertinfo
# instinfo: cmap-big-table.cmap_lincs_public_views.instinfo
# level3: cmap-big-table.cmap_lincs_public_views.L1000_Level3_cid
# level3_landmark: cmap-big-table.cmap_lincs_public_views.L1000_Level3_landmark
# level3_rid: cmap-big-table.cmap_lincs_public_views.L1000_Level3_rid
# level4: cmap-big-table.cmap_lincs_public_views.L1000_Level4_cid
# level4_landmark: cmap-big-table.cmap_lincs_public_views.L1000_Level4_landmark
# level4_rid: cmap-big-table.cmap_lincs_public_views.L1000_Level4_rid
# level5: cmap-big-table.cmap_lincs_public_views.L1000_Level5_cid
# level5_landmark: cmap-big-table.cmap_lincs_public_views.L1000_Level5_landmark
# level5_rid: cmap-big-table.cmap_lincs_public_views.L1000_Level5_rid
# siginfo: cmap-big-table.cmap_lincs_public_views.siginfo

# %% [markdown]
# ### Metadata for Level-5 data

# %%
query = "SELECT COUNT(DISTINCT(cid)) as num_level5_sigs FROM cmap-big-table.cmap_lincs_public_views.L1000_Level5"

cmap_query.run_query(query=query, client=bq_client).result().to_dataframe()

# %%
sig_metadata = cmap_query.cmap_sig(bq_client)
sig_metadata.head()
# Out:
#                                      sig_id              pert_id  \
# 0      ABY001_NCIH508_XH:BEVACIZUMAB:0.5:24          BEVACIZUMAB
# 1  ABY001_NCIH2073_XH:BEVACIZUMAB:0.0625:24          BEVACIZUMAB
# 2           AML001_CD34_6H:BRD-K68552125:10        BRD-K68552125
# 3         CNS001_HA1E_96H:EMPTY_VECTOR:-666  CNS001-EMPTY_VECTOR
# 4                         CPD003_PC3_6H:D03        BRD-K54094468
#
#        cmap_name       pert_type cell_iname pert_itime  pert_idose  nsample  \
# 0    BEVACIZUMAB         trt_aby    NCIH508       24 h   0.5 mg/ml        3
# 1    BEVACIZUMAB         trt_aby   NCIH2073       24 h  0.06 mg/ml        3
# 2  BRD-K68552125          trt_cp       CD34        6 h       10 uM        3
# 3   EMPTY_VECTOR  ctl_vector.cns       HA1E       96 h        None       41
# 4    remoxipride          trt_cp        PC3        6 h       10 uM        1
#
#                                           det_plates build_name project_code  \
# 0                           ABY001_NCIH508_XH_X1_B15       None          ABY
# 1                          ABY001_NCIH2073_XH_X1_B15       None          ABY
# 2  AML001_CD34_6H_X1_F1B10|AML001_CD34_6H_X2_F1B1...       None          AML
# 3                                               None       None          CNS
# 4                 CPD003_PC3_6H_X3.A2_B6_DUO52HI53LO       None          CPD
#
#    ss_ngene    cc_q75       tas
# 0       189  0.370000  0.267401
# 1       121  0.090000  0.105522
# 2       569  0.820000  0.690707
# 3       681  0.763151  0.728970
# 4         0  0.000000  0.000000

# %%
# Truncation of metadata table 
sig_metadata = sig_metadata.iloc[:,0:7]

# %%
sig_metadata.head()
# Out:
#                                      sig_id              pert_id  \
# 0      ABY001_NCIH508_XH:BEVACIZUMAB:0.5:24          BEVACIZUMAB
# 1  ABY001_NCIH2073_XH:BEVACIZUMAB:0.0625:24          BEVACIZUMAB
# 2           AML001_CD34_6H:BRD-K68552125:10        BRD-K68552125
# 3         CNS001_HA1E_96H:EMPTY_VECTOR:-666  CNS001-EMPTY_VECTOR
# 4                         CPD003_PC3_6H:D03        BRD-K54094468
#
#        cmap_name       pert_type cell_iname pert_itime  pert_idose
# 0    BEVACIZUMAB         trt_aby    NCIH508       24 h   0.5 mg/ml
# 1    BEVACIZUMAB         trt_aby   NCIH2073       24 h  0.06 mg/ml
# 2  BRD-K68552125          trt_cp       CD34        6 h       10 uM
# 3   EMPTY_VECTOR  ctl_vector.cns       HA1E       96 h        None
# 4    remoxipride          trt_cp        PC3        6 h       10 uM

# %% [markdown]
# ### Metadata for genetic pertutbations

# %%
genpert_info = cmap_query.cmap_genetic_perts(client=bq_client)

# Show a sample
genpert_info.sample(10)
# Out:
#               pert_id cmap_name   pert_type  gene_id  \
# 41269  BRDN0001485059    NDUFS1     trt_xpr     4719
# 22084  BRDN0001149366     RIOK2     trt_xpr    55781
# 33568  TRCN0000022184  ARHGAP35      trt_sh     2909
# 40179  TRCN0000036495    ARPC1B      trt_sh    10095
# 35795  BRDN0001518931     TTC37     trt_xpr     9652
# 40824  TRCN0000468230    CYP3A5      trt_oe     1577
# 4871   BRDN0001497958    VPREB1     trt_xpr     7441
# 31880  BRDN0001495292     IL1R1     trt_xpr     3554
# 41590     CGS001-5295    PIK3R1  trt_sh.cgs     5295
# 7005   TRCN0000039854     CHEK1      trt_sh     1111
#
#                                            gene_title       ensembl_id  \
# 41269  NADH:ubiquinone oxidoreductase core subunit S1  ENSG00000023228
# 22084                                    RIO kinase 2  ENSG00000058729
# 33568                Rho GTPase activating protein 35  ENSG00000160007
# 40179    actin related protein 2/3 complex subunit 1B  ENSG00000130429
# 35795              tetratricopeptide repeat domain 37  ENSG00000198677
# 40824   cytochrome P450 family 3 subfamily A member 5  ENSG00000106258
# 4871         V-set pre-B cell surrogate light chain 1  ENSG00000169575
# 31880                   interleukin 1 receptor type 1  ENSG00000115594
# 41590  phosphoinositide-3-kinase regulatory subunit 1  ENSG00000145675
# 7005                              checkpoint kinase 1  ENSG00000149554
#
#             gene_type  feature_space
# 41269  protein-coding  best inferred
# 22084  protein-coding  best inferred
# 33568  protein-coding  best inferred
# 40179  protein-coding  best inferred
# 35795  protein-coding  best inferred
# 40824  protein-coding  best inferred
# 4871   protein-coding       inferred
# 31880  protein-coding  best inferred
# 41590  protein-coding  best inferred
# 7005   protein-coding       landmark

# %%
genpert_info.shape
# Out:
# (44769, 8)

# %% [markdown]
# ### Types of genetic perturbations
# These are the genetic modifications used to induce the signatures. These will be used as edge types in the heterogeneous graph where each perturbation node will be connected to its target via an edge of a type of one of these genetic modifications.

# %%
genpert_info['pert_type'].unique()
# Out:
# array(['trt_oe', 'trt_sh', 'trt_sh.cgs', 'trt_si', 'trt_xpr'],
#       dtype=object)

# %% [markdown]
# ### Cell lines from the *cell-info* table
# To collect distinct *cell_inames* of the Central Nervous System (CNS) cell lineages.

# %%
qu = "SELECT DISTINCT cell_iname FROM cmap-big-table.cmap_lincs_public_views.cellinfo WHERE cell_lineage = 'central_nervous_system'"
cmap_query.run_query(query=qu, client=bq_client).result().to_dataframe()
# Out:
#   cell_iname
# 0        NEU
# 1        NPC
# 2      LN229
# 3      SKNSH
# 4     U251MG
# 5       YH13
# 6        GI1

# %%
## All genetic signatures of CNS cells
query = "SELECT DISTINCT(sig_id) FROM cmap-big-table.cmap_lincs_public_views.siginfo WHERE cell_iname IN ('NEU','NPC','LN229','SKNSH','U251MG','YH13','GI1') AND pert_type IN ('trt_oe', 'trt_sh', 'trt_sh.cgs', 'trt_si', 'trt_xpr')"

genetic_sig_ids = cmap_query.run_query(query=query, client=bq_client).result().to_dataframe()

# %%
genetic_cns_sig_meta = sig_metadata[sig_metadata['sig_id'].isin(genetic_sig_ids['sig_id'])]
genetic_cns_sig_meta.head()
# Out:
#                                        sig_id       pert_id     cmap_name  \
# 4527     TSAI001_221NPC1_XH:HDAC1-SHRNA2:-666  HDAC1-SHRNA2  HDAC1-SHRNA2
# 42630  TSAI001_APP11NPC1_XH:HDAC1-SHRNA4:-666  HDAC1-SHRNA4  HDAC1-SHRNA4
# 43722  TSAI001_APP11NPC1_XH:HDAC1-SHRNA5:-666  HDAC1-SHRNA5  HDAC1-SHRNA5
# 45733    TSAI001_221NPC1_XH:HDAC1-SHRNA4:-666  HDAC1-SHRNA4  HDAC1-SHRNA4
# 73873    TSAI001_221NPC1_XH:HDAC1-SHRNA5:-666  HDAC1-SHRNA5  HDAC1-SHRNA5
#
#       pert_type cell_iname pert_itime pert_idose
# 4527    trt_xpr        NPC       None       2 uM
# 42630   trt_xpr        NPC       None       2 uM
# 43722   trt_xpr        NPC       None       2 uM
# 45733   trt_xpr        NPC       None       2 uM
# 73873   trt_xpr        NPC       None       2 uM

# %%
genetic_cns_sig_meta.shape
# Out:
# (20635, 7)

# %%
genperts_cns_metadata = genpert_info[genpert_info['pert_id'].isin(genetic_cns_sig_meta['pert_id'])]
genperts_cns_metadata = genperts_cns_metadata.dropna()
genperts_cns_metadata.head()
# Out:
#              pert_id cmap_name pert_type  gene_id gene_title       ensembl_id  \
# 2467  BRDN0001487806       REN   trt_xpr     5972      renin  ENSG00000143839
# 2468  BRDN0001483163       REN   trt_xpr     5972      renin  ENSG00000143839
# 2469  BRDN0001501866      TBX4   trt_xpr     9496    T-box 4  ENSG00000121075
# 2470  BRDN0001502500      TBX4   trt_xpr     9496    T-box 4  ENSG00000121075
# 2475  BRDN0001488775       ALB   trt_xpr      213    albumin  ENSG00000163631
#
#            gene_type feature_space
# 2467  protein-coding      inferred
# 2468  protein-coding      inferred
# 2469  protein-coding      inferred
# 2470  protein-coding      inferred
# 2475  protein-coding      inferred

# %%
# Map signature ids in the metadata table to perturbation ids in genetic_perturbations table
merged_df = pd.merge(genperts_cns_metadata, genetic_cns_sig_meta[['sig_id', 'pert_id']], on='pert_id', how='left')
merged_df = merged_df.astype('str')
merged_df.head()
# Out:
#           pert_id cmap_name pert_type gene_id gene_title       ensembl_id  \
# 0  BRDN0001487806       REN   trt_xpr    5972      renin  ENSG00000143839
# 1  BRDN0001483163       REN   trt_xpr    5972      renin  ENSG00000143839
# 2  BRDN0001501866      TBX4   trt_xpr    9496    T-box 4  ENSG00000121075
# 3  BRDN0001502500      TBX4   trt_xpr    9496    T-box 4  ENSG00000121075
# 4  BRDN0001488775       ALB   trt_xpr     213    albumin  ENSG00000163631
#
#         gene_type feature_space                     sig_id
# 0  protein-coding      inferred  XPR009_U251MG.311_96H:D02
# 1  protein-coding      inferred  XPR009_U251MG.311_96H:H22
# 2  protein-coding      inferred  XPR025_U251MG.311_96H:J07
# 3  protein-coding      inferred  XPR025_U251MG.311_96H:N11
# 4  protein-coding      inferred  XPR009_U251MG.311_96H:P11

# %%
# Use gene_mapping_dictionary to select only signatures with targets present in the hetero-graph
import json
file_path = '/home/ahmed_kh/project/graph/genes/edge_index/mapping_dicts/genes_dict.json'
with open(file_path, 'r') as json_file:
    genes_dict_json = json.load(json_file)

#convert back strings into integers
    genes_dict = {int(key): value for key, value in genes_dict_json.items()}
    
print(len(genes_dict))
# Out:
# 18315

# %%
genes = list({str(key) for key, value in genes_dict.items()})
merged_df = merged_df[merged_df['gene_id'].isin(genes)]
merged_df.head()
# Out:
#           pert_id cmap_name pert_type gene_id gene_title       ensembl_id  \
# 0  BRDN0001487806       REN   trt_xpr    5972      renin  ENSG00000143839
# 1  BRDN0001483163       REN   trt_xpr    5972      renin  ENSG00000143839
# 2  BRDN0001501866      TBX4   trt_xpr    9496    T-box 4  ENSG00000121075
# 3  BRDN0001502500      TBX4   trt_xpr    9496    T-box 4  ENSG00000121075
# 4  BRDN0001488775       ALB   trt_xpr     213    albumin  ENSG00000163631
#
#         gene_type feature_space                     sig_id
# 0  protein-coding      inferred  XPR009_U251MG.311_96H:D02
# 1  protein-coding      inferred  XPR009_U251MG.311_96H:H22
# 2  protein-coding      inferred  XPR025_U251MG.311_96H:J07
# 3  protein-coding      inferred  XPR025_U251MG.311_96H:N11
# 4  protein-coding      inferred  XPR009_U251MG.311_96H:P11

# %% [markdown]
# This is now the final list of signature IDs that we want to download.

# %% [markdown]
# ### *Perturbation::target* relathionships
# This is the table that will be used to create the "perturbation::target" relationship module in the graph

# %%
signature_moa_target = merged_df[['sig_id','pert_type','gene_id']].copy()
signature_moa_target.head()
# Out:
#                       sig_id pert_type gene_id
# 0  XPR009_U251MG.311_96H:D02   trt_xpr    5972
# 1  XPR009_U251MG.311_96H:H22   trt_xpr    5972
# 2  XPR025_U251MG.311_96H:J07   trt_xpr    9496
# 3  XPR025_U251MG.311_96H:N11   trt_xpr    9496
# 4  XPR009_U251MG.311_96H:P11   trt_xpr     213

# %%
signature_moa_target.shape
# Out:
# (20023, 3)

# %%
# Save metadata as a csv file
csv_filename = 'signature_moa_target.csv'
signature_moa_target.to_csv(csv_filename, index=False)

# %% [markdown]
# ### Signature querying

# %%
# signatures to be queried
signatures = signature_moa_target['sig_id'].to_list()

# Gene IDs to be queried
AD_signature = pd.read_csv("AD_signature.csv")
AD_signature = AD_signature.astype('str')
AD_signature = AD_signature['Gene.ID'].to_list()
AD_sig = AD_sig.iloc[:,1:-1]

# %%
# Set the batch size
batch_size = 1000
df = pd.DataFrame()

# Loop through the list in batches
for i in range(0, len(signatures), batch_size):
    batch = signatures[i:i+batch_size]
   
    # Run the query
    data_numerical = cmap_query.cmap_matrix(bq_client, data_level='level5', feature_space='bing', cid=batch, rid=AD_signature, chunk_size=1000)

    # Convert the GCTOO matrix to a pandas DataFrame
    dfx = data_numerical.data_df
    
    dft = dfx.transpose()
    
    df = pd.concat([df,dft],axis=0)
    
print("Done!")
# Out:
# Running query ... (1/1)
# Total bytes processed: 9.7GiB
# Total bytes billed: 9.7GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 14.1GiB
# Total bytes billed: 14.1GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 13.1GiB
# Total bytes billed: 13.1GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 11.9GiB
# Total bytes billed: 11.9GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 13.3GiB
# Total bytes billed: 13.3GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 12.2GiB
# Total bytes billed: 12.2GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 13.2GiB
# Total bytes billed: 13.2GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 12.1GiB
# Total bytes billed: 12.1GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 12.3GiB
# Total bytes billed: 12.3GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 12.7GiB
# Total bytes billed: 12.7GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 9.0GiB
# Total bytes billed: 9.0GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 10.9GiB
# Total bytes billed: 10.9GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 12.4GiB
# Total bytes billed: 12.4GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 13.1GiB
# Total bytes billed: 13.1GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 13.1GiB
# Total bytes billed: 13.1GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 13.6GiB
# Total bytes billed: 13.6GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 13.0GiB
# Total bytes billed: 13.0GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 13.6GiB
# Total bytes billed: 13.6GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 13.1GiB
# Total bytes billed: 13.1GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 13.0GiB
# Total bytes billed: 13.0GiB
# Pivoting Dataframes to GCT objects
# Complete
# Running query ... (1/1)
# Total bytes processed: 1.1GiB
# Total bytes billed: 1.1GiB
# Pivoting Dataframes to GCT objects
# Complete
# Done!

# %%
df.shape
# Out:
# (20023, 6056)

# %%
df.iloc[:10,:10]
# Out:
# rid                                      100     10000     10001     10005  \
# cid
# CGS001_NPC_96H:HBE1:1.5            -0.218373  0.008493 -0.480829  0.166468
# CGS001_NPC_96H:LHX3:1.5            -0.570863 -0.502525  0.165043  0.244646
# CGS001_NPC_96H:PRKCE:1.5            0.347789  0.293864 -0.517908 -0.106490
# CGS001_NPC_96H:SENP5:1.5            0.376575  0.393675 -0.609250  0.546325
# KDB005_NPC_96H:TRCN0000062310:-666 -0.058650 -0.945650  0.435700  0.466750
# KDB005_NPC_96H:TRCN0000062311:-666  0.811800  1.733000 -1.654200  0.625900
# KDB006_NPC_96H:K06                 -0.212064 -0.372232 -0.055138  0.247922
# KDB006_NPC_96H:K14                  0.247382  0.426326 -1.069436 -0.204103
# KDB006_NPC_96H:M18                 -1.155408  0.335541 -0.147187  0.549799
# KDB006_NPC_96H:TRCN0000059938:-666 -0.454374 -0.555515  0.086916  0.248565
#
# rid                                    10006     10007     10010  100129250  \
# cid
# CGS001_NPC_96H:HBE1:1.5            -0.328992 -0.121826  0.136187  -0.508528
# CGS001_NPC_96H:LHX3:1.5             0.117853  0.229546  0.008000   0.414267
# CGS001_NPC_96H:PRKCE:1.5            0.486904 -0.141105  0.551190   0.077079
# CGS001_NPC_96H:SENP5:1.5            0.045675 -0.718825  0.562125   0.346800
# KDB005_NPC_96H:TRCN0000062310:-666  0.124650 -1.131450  0.509300   0.741000
# KDB005_NPC_96H:TRCN0000062311:-666 -0.033300 -0.306200  0.614950  -0.047400
# KDB006_NPC_96H:K06                 -0.265903  0.701970  0.210728  -0.730278
# KDB006_NPC_96H:K14                  0.434191 -1.240098  0.259844  -0.158531
# KDB006_NPC_96H:M18                 -0.597942  0.785241 -0.809739  -0.270088
# KDB006_NPC_96H:TRCN0000059938:-666 -0.577242  0.934408  0.249712  -0.873616
#
# rid                                 100129482  100131755
# cid
# CGS001_NPC_96H:HBE1:1.5              0.243526   0.635878
# CGS001_NPC_96H:LHX3:1.5             -0.613329  -0.282516
# CGS001_NPC_96H:PRKCE:1.5             0.066313   0.667602
# CGS001_NPC_96H:SENP5:1.5             0.215425   0.182775
# KDB005_NPC_96H:TRCN0000062310:-666  -0.466700  -0.551050
# KDB005_NPC_96H:TRCN0000062311:-666   0.897550   0.916600
# KDB006_NPC_96H:K06                  -0.457543   0.144343
# KDB006_NPC_96H:K14                   0.750229   1.785550
# KDB006_NPC_96H:M18                   0.826635   0.246780
# KDB006_NPC_96H:TRCN0000059938:-666  -0.389473  -0.068221

# %%
# Mapping IDs and sorting the dataframe
file_path = 'mapping_dicts/genperts_dict.json'
with open(file_path, 'r') as json_file:
    genperts_json = json.load(json_file)

    genperts_dict = {str(key): value for key, value in genperts_json.items()}
    
print(len(genperts_dict))
# Out:
# 20023

# %%
df.index = df.index.map(genperts_dict)
df = df.sort_index()
df
# Out:
#             100     10000     10001     10005     10006     10007     10010  \
# 0      0.174898  0.170660 -0.327706 -1.012201 -0.709069  0.590302  0.317491
# 1      0.023692 -0.621700 -0.214531  0.067540 -0.066525  0.305235  0.673813
# 2      0.406850  0.775148 -0.288365  1.054073 -0.470195  0.224927 -0.055932
# 3      0.012266  0.370053  0.905270  0.524906  1.090123 -1.512671 -0.746616
# 4      0.680962 -1.441959  0.123246 -0.414082 -0.119506 -0.310105  0.768365
# ...         ...       ...       ...       ...       ...       ...       ...
# 20018  1.630630 -1.057249 -1.483222 -0.694036  0.392080 -0.302878 -0.181074
# 20019  1.910709 -0.613249 -1.384393  1.606892 -0.516433 -0.464828  0.489844
# 20020  1.285126  0.607435 -1.041552 -0.743960 -0.831314 -0.496065 -0.702506
# 20021  0.069787 -0.865963 -0.208207 -0.925451 -0.413606  0.946464  0.211409
# 20022  0.407192 -1.007266 -0.520059 -1.015668 -0.387113  1.611287 -0.047165
#
#        100129250  100129482  100131755  ...      9973      9976      9978  \
# 0      -0.336832  -0.622616  -1.192824  ... -0.020990 -0.943036 -0.457074
# 1       0.026184  -0.026370   0.469255  ...  0.625724  0.280934 -0.312827
# 2      -0.041696  -0.939581   0.170502  ... -0.822419  0.436913 -0.108121
# 3      -0.560953  -0.119623  -0.714175  ... -0.903741 -0.134229  0.230682
# 4       0.300217   0.037321   0.057293  ... -1.274699  0.608310 -0.498205
# ...          ...        ...        ...  ...       ...       ...       ...
# 20018  -1.345645  -0.120782   1.596910  ...  0.896386  0.376598  0.010688
# 20019   0.257911  -0.760184   0.645760  ...  1.832853 -0.387472 -0.745996
# 20020   0.159211   0.202441   1.274807  ...  1.931300 -0.839873  0.334764
# 20021  -0.306070  -1.471482  -1.303913  ... -0.597694 -0.450268 -0.335929
# 20022  -0.131920  -0.920796  -0.591502  ...  0.797604 -0.116052  1.766035
#
#             998      9980      9987      9988      9990      9991      9997
# 0     -0.451099 -0.275676  0.025439 -0.940749  0.108191  0.012258  0.436765
# 1      0.258809  0.337565 -0.288991 -0.516484  0.399671 -0.623557 -0.335016
# 2      0.189611  0.088665 -0.411371  0.159655 -0.312251 -0.004310  0.327478
# 3      0.673075 -0.450610  0.643537 -0.437256 -0.244052 -0.270511 -0.391445
# 4     -1.115365 -0.178106 -0.262965  0.487434 -0.042183  1.015008 -0.002290
# ...         ...       ...       ...       ...       ...       ...       ...
# 20018 -0.353705 -0.522536 -0.718549 -1.132831 -0.174150 -0.610226  0.576494
# 20019 -0.018421 -0.794105 -0.904071 -0.857446 -0.791354  1.414317 -0.423272
# 20020 -0.183769 -0.945705 -0.867503 -0.121041  0.739108 -0.742083  0.058644
# 20021  0.760301 -0.961826  0.312094 -0.615488 -1.047882  0.030394 -0.519334
# 20022  0.289661  0.024769 -0.771800 -1.101306  0.341335  0.064232 -0.595539
#
# [20023 rows x 6056 columns]

# %%
# Save the signatures as a csv file
df.to_csv("20023_6056_signatures.csv", index=True)
